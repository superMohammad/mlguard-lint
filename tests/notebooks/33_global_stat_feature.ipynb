# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df["age"] = df["age"].fillna(df["age"].mean())
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=["target"]), df["target"], stratify=df["target"], random_state=0)
