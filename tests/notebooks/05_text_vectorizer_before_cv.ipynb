# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_val_score
X_text = TfidfVectorizer().fit_transform(texts)
cross_val_score(clf, X_text, y, cv=5)
